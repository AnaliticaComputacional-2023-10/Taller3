# %% [markdown]
# # Taller 3

# %%
import pandas as pd

# %%
df = pd.read_csv('https://raw.githubusercontent.com/plotly/datasets/master/gapminderDataFiveYear.csv')
df
# Out:
#           country  year         pop continent  lifeExp   gdpPercap
# 0     Afghanistan  1952   8425333.0      Asia   28.801  779.445314
# 1     Afghanistan  1957   9240934.0      Asia   30.332  820.853030
# 2     Afghanistan  1962  10267083.0      Asia   31.997  853.100710
# 3     Afghanistan  1967  11537966.0      Asia   34.020  836.197138
# 4     Afghanistan  1972  13079460.0      Asia   36.088  739.981106
# ...           ...   ...         ...       ...      ...         ...
# 1699     Zimbabwe  1987   9216418.0    Africa   62.351  706.157306
# 1700     Zimbabwe  1992  10704340.0    Africa   60.377  693.420786
# 1701     Zimbabwe  1997  11404948.0    Africa   46.809  792.449960
# 1702     Zimbabwe  2002  11926563.0    Africa   39.989  672.038623
# 1703     Zimbabwe  2007  12311143.0    Africa   43.487  469.709298
#
# [1704 rows x 6 columns]

# %%
df.groupby(['year', 'continent']).agg(meanLifeExp=('lifeExp', 'mean')).reset_index()
df.groupby(['year', 'continent']).agg(meanLifeExp=('lifeExp', 'mean'), maxLifeExp=('lifeExp', 'max'), minLifeExp=('lifeExp', 'min'), stdLifeExp=('lifeExp', 'std'))
# Out:
#                 meanLifeExp  maxLifeExp  minLifeExp  stdLifeExp
# year continent
# 1952 Africa       39.135500      52.724      30.000    5.151581
#      Americas     53.279840      68.750      37.579    9.326082
#      Asia         46.314394      65.390      28.801    9.291751
#      Europe       64.408500      72.670      43.585    6.361088
#      Oceania      69.255000      69.390      69.120    0.190919
# 1957 Africa       41.266346      58.089      31.570    5.620123
#      Americas     55.960280      69.960      40.696    9.033192
#      Asia         49.318544      67.840      30.332    9.635429
#      Europe       66.703067      73.470      48.079    5.295805
#      Oceania      70.295000      70.330      70.260    0.049497
# 1962 Africa       43.319442      60.246      32.767    5.875364
#      Americas     58.398760      71.300      43.428    8.503544
#      Asia         51.563223      69.390      31.997    9.820632
# ...

# %%
df[df.year == 1952].groupby(['continent']).agg(mean=('lifeExp', 'mean'))
# Out:
#                 mean
# continent
# Africa     39.135500
# Americas   53.279840
# Asia       46.314394
# Europe     64.408500
# Oceania    69.255000

# %%
df.groupby(['continent', 'year']).agg(mean=('lifeExp', 'mean'))
# Out:
#                      mean
# continent year
# Africa    1952  39.135500
#           1957  41.266346
#           1962  43.319442
#           1967  45.334538
#           1972  47.450942
#           1977  49.580423
#           1982  51.592865
#           1987  53.344788
#           1992  53.629577
#           1997  53.598269
#           2002  53.325231
#           2007  54.806038
# Americas  1952  53.279840
#           1957  55.960280
#           1962  58.398760
#           1967  60.410920
#           1972  62.394920
#           1977  64.391560
#           1982  66.228840
#           1987  68.090720
#           1992  69.568360
#           1997  71.150480
#           2002  72.422040
#           2007  73.608120
# Asia      1952  46.314394
#           1957  49.318544
#           1962  51.563223
#           1967  54.663640
#           1972  57.319269
#           1977  59.610556
#           1982  62.617939
#           1987  64.851182
#           1992  66.537212
#           1997  68.020515
# ...

# %%
df.plot(x='pop', y='gdpPercap', kind='scatter')
# Out:
# c:\Users\SGM\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\plotting\_matplotlib\core.py:1114: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   scatter = ax.scatter(
# <AxesSubplot: xlabel='pop', ylabel='gdpPercap'>

# %%
marks = {continent: continent for continent in df["continent"].unique()}
marks
# Out:
# {'Asia': 'Asia',
#  'Europe': 'Europe',
#  'Africa': 'Africa',
#  'Americas': 'Americas',
#  'Oceania': 'Oceania'}

# %%
marks = {}
cont = 1
for c in df["continent"].unique():
    marks[cont] = c
    cont += 1
marks
# Out:
# {1: 'Asia', 2: 'Europe', 3: 'Africa', 4: 'Americas', 5: 'Oceania'}
